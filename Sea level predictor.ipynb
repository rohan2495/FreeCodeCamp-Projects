# %%
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import linregress

def draw_plot():
    # Read data from file
    df = pd.read_csv('epa-sea-level.csv')

    # Create scatter plot
    df.plot.scatter(x='Year',y='CSIRO Adjusted Sea Level')

    # Create first line of best fit
    x= df['Year']
    y= df['CSIRO Adjusted Sea Level']
    
    slope, intercept, r_value, p_value, std_err = linregress(x=df['Year'],y=df['CSIRO Adjusted Sea Level'])
    
    x2 = list(range(1880, 2052)) #Creat
    y2 = []
    for year in x2:
        y2.append(intercept + slope*year)
    df.plot.scatter(x='Year',y='CSIRO Adjusted Sea Level')
    plt.plot(x2,y2,'r', label = 'Best fit line')

    # Create second line of best fit
    df_new = df[df['Year']>2000]
    
    slope2, intercept2, r_value2, p_value2, std_err2 = linregress(x=df_new['Year'],y=df_new['CSIRO Adjusted Sea Level'])

    x3 = list(range(2000, 2052))
    y3 = []
    for year in x3:
        y3.append(intercept2 + slope2*year)

    plt.plot(x3,y3,'b', label = 'Best fit line: rise since 2000')
    
    # Add labels and title
    plt.xlabel('Year')
    plt.ylabel('Sea Level (inches)')
    plt.title('Rise in Sea Level')
    
    # Save plot and return data for testing (DO NOT MODIFY)
    plt.savefig('sea_level_plot.png')
    return plt.gca()

# %%
#import sea_level_predictor
#from unittest import main

# Test your function by calling it here
draw_plot()

# Run unit tests automatically
#main(module='test_module', exit=False)

# %%
df = pd.read_csv('epa-sea-level.csv')
df.head()
# Out:
#    Year  CSIRO Adjusted Sea Level  Lower Error Bound  Upper Error Bound  \
# 0  1880                  0.000000          -0.952756           0.952756
# 1  1881                  0.220472          -0.732283           1.173228
# 2  1882                 -0.440945          -1.346457           0.464567
# 3  1883                 -0.232283          -1.129921           0.665354
# 4  1884                  0.590551          -0.283465           1.464567
#
#    NOAA Adjusted Sea Level
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN

# %%
df.plot.scatter(x='Year',y='CSIRO Adjusted Sea Level')

# %%
linregress(x=df['Year'],y=df['CSIRO Adjusted Sea Level'])
# Out:
# LinregressResult(slope=0.0630445840121348, intercept=-119.06594196773978, rvalue=0.984757131182585, pvalue=3.7886969791131554e-102, stderr=0.000969211871328715)

# %%
x= df['Year']
y= df['CSIRO Adjusted Sea Level']
slope, intercept, r_value, p_value, std_err = linregress(x=df['Year'],y=df['CSIRO Adjusted Sea Level'])
df.plot.scatter(x='Year',y='CSIRO Adjusted Sea Level')
plt.plot(x, intercept + slope*x, 'r', label='fitted line')

# %%
x2 = list(range(1880, 2052))
y2 = []
for year in x2:
    y2.append(intercept + slope*year)
df.plot.scatter(x='Year',y='CSIRO Adjusted Sea Level')
plt.plot(x2,y2,'r', label = 'Best fit line')

# %%
df_new = df[df['Year']>=2000]
slope2, intercept2, r_value2, p_value2, std_err2 = linregress(x=df_new['Year'],y=df_new['CSIRO Adjusted Sea Level'])

x3 = list(range(2000, 2050))
y3 = []
for year in x3:
    y3.append(intercept2 + slope2*year)

df.plot.scatter(x='Year',y='CSIRO Adjusted Sea Level')
plt.plot(x2,y2,'r', label = 'Best fit line')
plt.plot(x3,y3,'b', label = 'Best fit line: rise since 2000')

plt.xlabel('Year')
plt.ylabel('Sea Level (inches)')
plt.title('Rise in Sea Level')
# Out:
# Text(0.5, 1.0, 'Rise in Sea Level')

# %%
y3
# Out:
# [7.06107985777146,
#  7.227507131103323,
#  7.393934404435242,
#  7.560361677767105,
#  7.726788951098968,
#  7.89321622443083,
#  8.059643497762693,
#  8.226070771094555,
#  8.392498044426418,
#  8.55892531775828,
#  8.725352591090143,
#  8.891779864422006,
#  9.058207137753925,
#  9.224634411085788,
#  9.39106168441765,
#  9.557488957749513,
#  9.723916231081375,
#  9.890343504413238,
#  10.0567707777451,
#  10.223198051076963,
#  10.389625324408826,
#  10.556052597740688,
#  10.72247987107255,
#  10.88890714440447,
#  11.055334417736333,
#  11.221761691068195,
#  11.388188964400058,
#  11.55461623773192,
#  11.721043511063783,
#  11.887470784395646,
#  12.053898057727508,
#  12.220325331059371,
#  12.386752604391233,
#  12.553179877723153,
#  12.719607151055015,
#  12.886034424386878,
#  13.05246169771874,
#  13.218888971050603,
#  13.385316244382466,
#  13.551743517714328,
#  13.718170791046191,
#  13.884598064378054,
#  14.051025337709916,
#  14.217452611041836,
# ...
